# %%
#@title Run this to download data and prepare our environment!  { display-mode: "form" }

import cv2
import dlib
import pickle
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import itertools 

import urllib.request
 
from sklearn import metrics
from scipy.spatial import distance
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
from tqdm import tqdm,tqdm_pandas
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import re
import keras

from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy, binary_crossentropy
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model

# grab tools from our tensorflow and keras toolboxes!
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import optimizers

warnings.filterwarnings("ignore")

'''
Plots the confusion Matrix and saves it
'''
def plot_confusion_matrix(y_true,y_predicted):
  cm = metrics.confusion_matrix(y_true, y_predicted)
  print ("Plotting the Confusion Matrix")
  labels = list(label_map.values())
  df_cm = pd.DataFrame(cm,index = labels,columns = labels)
  fig = plt.figure()
  res = sns.heatmap(df_cm, annot=True,cmap='Blues', fmt='g')
  plt.yticks([0.5,1.5,2.5,3.5,4.5], labels,va='center')
  plt.title('Confusion Matrix - TestData')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
 
  plt.show()
  plt.close()

def plot_graphs(history, best):
  
  plt.figure(figsize=[10,4])
  # summarize history for accuracy
  plt.subplot(121)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy across training\n best accuracy of %.02f'%best[1])
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  
  # summarize history for loss
  plt.subplot(122)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss across training\n best loss of %.02f'%best[0])
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

#Integer to Label Mapping
label_map = {"0":"ANGRY","1":"HAPPY","2":"SAD","3":"SURPRISE","4":"NEUTRAL"}

# %%
# we'll use the same epochs and batch size as above
width, height = 160, 128

# %%
## X_train_cnn = X_train.reshape(len(X_train),height,width)
## X_test_cnn = X_test.reshape(len(X_test),height,width)

# we've converted them to images
## print(X_train_cnn.shape) 
# now we add one more dimension for model compatibility
## print(X_test_cnn.shape) 

train_ds = tf.keras.utils.image_dataset_from_directory(  
  "C:\\Users\\jaden\\OneDrive\\Documents\\GitHub\\ScienceFair_AI_Models_2023\\jpgTrainingData\\Train",  
  seed=123,  
  image_size = (height, width),
  batch_size = 2, color_mode = "grayscale")

val_ds = tf.keras.utils.image_dataset_from_directory(  
  "C:\\Users\\jaden\\OneDrive\\Documents\\GitHub\\ScienceFair_AI_Models_2023\\jpgTrainingData\\Val",  
  seed=123,  
  image_size = (height, width),
  batch_size = 1, color_mode = "grayscale") 

test_ds = tf.keras.utils.image_dataset_from_directory(  
  "C:\\Users\\jaden\\OneDrive\\Documents\\GitHub\\ScienceFair_AI_Models_2023\\jpgTrainingData\\Test",  
  seed=123,  
  image_size = (height, width),
  batch_size = 1, color_mode = "grayscale")
# Out:
# Found 90 files belonging to 2 classes.
# Found 10 files belonging to 2 classes.
# Found 12 files belonging to 2 classes.

# %%
# now we add one more dimension for model compatibility
## X_train_cnn = np.expand_dims(X_train_cnn,3)
## X_test_cnn = np.expand_dims(X_test_cnn,3)

## print(X_train_cnn.shape)

# %%
#@title Instructor Solution

# pedagogically, it's probably a good idea to not use this model, but it's nice to have in case
# comparing the basic model above with transfer learning more clearly motivates that approach

cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', input_shape=(height, width, 1), kernel_regularizer=l2(0.01)))
cnn_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
cnn_model.add(Dropout(0.5))

cnn_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
cnn_model.add(Dropout(0.5))

cnn_model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
cnn_model.add(Dropout(0.5))

cnn_model.add(Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(512, kernel_size=(3, 3), activation='relu', padding='same'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
cnn_model.add(Dropout(0.5))

cnn_model.add(Flatten())

cnn_model.add(Dense(512, activation='relu'))
cnn_model.add(Dropout(0.4))
cnn_model.add(Dense(256, activation='relu'))
cnn_model.add(Dropout(0.4))
cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(1, activation='softmax'))

# %%
#Saves the Best Model Based on Val Loss
checkpoint = ModelCheckpoint('best_cnn_model.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')  

# compliling the model with adam optimizer and categorical crossentropy loss
cnn_model.compile(loss=binary_crossentropy, optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999), metrics=['accuracy'])

# training the model
cnn_history = cnn_model.fit(train_ds, validation_data = val_ds, batch_size=2, epochs=50, verbose=1, 
                            callbacks=[checkpoint], shuffle=True)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 45/45 [==============================] - ETA: 0s - loss: 11.3483 - accuracy: 0.3222
# Epoch 1: val_loss improved from inf to 709.17450, saving model to best_cnn_model.h5
# 45/45 [==============================] - 24s 463ms/step - loss: 11.3483 - accuracy: 0.3222 - val_loss: 709.1745 - val_accuracy: 0.3000
# Epoch 2/50
# 45/45 [==============================] - ETA: 0s - loss: 12.1436 - accuracy: 0.3222
# Epoch 2: val_loss improved from 709.17450 to 649.73535, saving model to best_cnn_model.h5
# 45/45 [==============================] - 21s 472ms/step - loss: 12.1436 - accuracy: 0.3222 - val_loss: 649.7354 - val_accuracy: 0.3000
# Epoch 3/50
# 45/45 [==============================] - ETA: 0s - loss: 8.1994 - accuracy: 0.3222
# Epoch 3: val_loss improved from 649.73535 to 28.60740, saving model to best_cnn_model.h5
# 45/45 [==============================] - 22s 490ms/step - loss: 8.1994 - accuracy: 0.3222 - val_loss: 28.6074 - val_accuracy: 0.3000
# Epoch 4/50
# 45/45 [==============================] - ETA: 0s - loss: 7.2467 - accuracy: 0.3222
# Epoch 4: val_loss improved from 28.60740 to 6.69094, saving model to best_cnn_model.h5
# 45/45 [==============================] - 19s 431ms/step - loss: 7.2467 - accuracy: 0.3222 - val_loss: 6.6909 - val_accuracy: 0.3000
# Epoch 5/50
# 45/45 [==============================] - ETA: 0s - loss: 6.1823 - accuracy: 0.3222
# Epoch 5: val_loss improved from 6.69094 to 2.16479, saving model to best_cnn_model.h5
# 45/45 [==============================] - 20s 446ms/step - loss: 6.1823 - accuracy: 0.3222 - val_loss: 2.1648 - val_accuracy: 0.3000
# Epoch 6/50
# 45/45 [==============================] - ETA: 0s - loss: 7.2360 - accuracy: 0.3222
# Epoch 6: val_loss improved from 2.16479 to 1.86041, saving model to best_cnn_model.h5
# 45/45 [==============================] - 21s 466ms/step - loss: 7.2360 - accuracy: 0.3222 - val_loss: 1.8604 - val_accuracy: 0.3000
# Epoch 7/50
# 45/45 [==============================] - ETA: 0s - loss: 5.3415 - accuracy: 0.3222
# Epoch 7: val_loss did not improve from 1.86041
# 45/45 [==============================] - 21s 462ms/step - loss: 5.3415 - accuracy: 0.3222 - val_loss: 2.7978 - val_accuracy: 0.3000
# Epoch 8/50
# 45/45 [==============================] - ETA: 0s - loss: 4.6986 - accuracy: 0.3222
# Epoch 8: val_loss did not improve from 1.86041
# 45/45 [==============================] - 22s 480ms/step - loss: 4.6986 - accuracy: 0.3222 - val_loss: 2.4547 - val_accuracy: 0.3000
# Epoch 9/50
# 45/45 [==============================] - ETA: 0s - loss: 2.9786 - accuracy: 0.3222
# Epoch 9: val_loss did not improve from 1.86041
# 45/45 [==============================] - 21s 475ms/step - loss: 2.9786 - accuracy: 0.3222 - val_loss: 2.7044 - val_accuracy: 0.3000
# Epoch 10/50
# 45/45 [==============================] - ETA: 0s - loss: 4.0944 - accuracy: 0.3222
# Epoch 10: val_loss improved from 1.86041 to 1.41634, saving model to best_cnn_model.h5
# 45/45 [==============================] - 21s 466ms/step - loss: 4.0944 - accuracy: 0.3222 - val_loss: 1.4163 - val_accuracy: 0.3000
# Epoch 11/50
# 45/45 [==============================] - ETA: 0s - loss: 3.6310 - accuracy: 0.3222
# Epoch 11: val_loss improved from 1.41634 to 0.73036, saving model to best_cnn_model.h5
# 45/45 [==============================] - 21s 479ms/step - loss: 3.6310 - accuracy: 0.3222 - val_loss: 0.7304 - val_accuracy: 0.3000
# Epoch 12/50
# 45/45 [==============================] - ETA: 0s - loss: 2.5616 - accuracy: 0.3222
# Epoch 12: val_loss did not improve from 0.73036
# 45/45 [==============================] - 21s 470ms/step - loss: 2.5616 - accuracy: 0.3222 - val_loss: 0.9711 - val_accuracy: 0.3000
# Epoch 13/50
# 45/45 [==============================] - ETA: 0s - loss: 2.7747 - accuracy: 0.3222
# Epoch 13: val_loss improved from 0.73036 to 0.61643, saving model to best_cnn_model.h5
# 45/45 [==============================] - 23s 507ms/step - loss: 2.7747 - accuracy: 0.3222 - val_loss: 0.6164 - val_accuracy: 0.3000
# Epoch 14/50
# 45/45 [==============================] - ETA: 0s - loss: 2.0283 - accuracy: 0.3222
# Epoch 14: val_loss improved from 0.61643 to 0.60197, saving model to best_cnn_model.h5
# 45/45 [==============================] - 22s 490ms/step - loss: 2.0283 - accuracy: 0.3222 - val_loss: 0.6020 - val_accuracy: 0.3000
# Epoch 15/50
# 45/45 [==============================] - ETA: 0s - loss: 1.5581 - accuracy: 0.3222
# Epoch 15: val_loss did not improve from 0.60197
# 45/45 [==============================] - 21s 475ms/step - loss: 1.5581 - accuracy: 0.3222 - val_loss: 0.6891 - val_accuracy: 0.3000
# Epoch 16/50
# 45/45 [==============================] - ETA: 0s - loss: 1.4303 - accuracy: 0.3222
# Epoch 16: val_loss did not improve from 0.60197
# 45/45 [==============================] - 23s 507ms/step - loss: 1.4303 - accuracy: 0.3222 - val_loss: 1.0426 - val_accuracy: 0.3000
# Epoch 17/50
# 45/45 [==============================] - ETA: 0s - loss: 1.9336 - accuracy: 0.3222
# Epoch 17: val_loss did not improve from 0.60197
# 45/45 [==============================] - 22s 489ms/step - loss: 1.9336 - accuracy: 0.3222 - val_loss: 0.6697 - val_accuracy: 0.3000
# Epoch 18/50
# 45/45 [==============================] - ETA: 0s - loss: 1.6011 - accuracy: 0.3222
# Epoch 18: val_loss improved from 0.60197 to 0.55147, saving model to best_cnn_model.h5
# 45/45 [==============================] - 22s 498ms/step - loss: 1.6011 - accuracy: 0.3222 - val_loss: 0.5515 - val_accuracy: 0.3000
# Epoch 19/50
# 45/45 [==============================] - ETA: 0s - loss: 1.1120 - accuracy: 0.3222
# Epoch 19: val_loss did not improve from 0.55147
# 45/45 [==============================] - 22s 493ms/step - loss: 1.1120 - accuracy: 0.3222 - val_loss: 1.0234 - val_accuracy: 0.3000
# Epoch 20/50
# 45/45 [==============================] - ETA: 0s - loss: 1.3023 - accuracy: 0.3222
# Epoch 20: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 505ms/step - loss: 1.3023 - accuracy: 0.3222 - val_loss: 0.6517 - val_accuracy: 0.3000
# Epoch 21/50
# 45/45 [==============================] - ETA: 0s - loss: 1.0748 - accuracy: 0.3222
# Epoch 21: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 510ms/step - loss: 1.0748 - accuracy: 0.3222 - val_loss: 0.6118 - val_accuracy: 0.3000
# Epoch 22/50
# 45/45 [==============================] - ETA: 0s - loss: 0.8807 - accuracy: 0.3222
# Epoch 22: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 505ms/step - loss: 0.8807 - accuracy: 0.3222 - val_loss: 0.8686 - val_accuracy: 0.3000
# Epoch 23/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.3222
# Epoch 23: val_loss did not improve from 0.55147
# 45/45 [==============================] - 22s 499ms/step - loss: 0.7473 - accuracy: 0.3222 - val_loss: 0.6761 - val_accuracy: 0.3000
# Epoch 24/50
# 45/45 [==============================] - ETA: 0s - loss: 0.9811 - accuracy: 0.3222
# Epoch 24: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 526ms/step - loss: 0.9811 - accuracy: 0.3222 - val_loss: 0.8820 - val_accuracy: 0.3000
# Epoch 25/50
# 45/45 [==============================] - ETA: 0s - loss: 0.9592 - accuracy: 0.3222
# Epoch 25: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 513ms/step - loss: 0.9592 - accuracy: 0.3222 - val_loss: 0.6421 - val_accuracy: 0.3000
# Epoch 26/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7346 - accuracy: 0.3222
# Epoch 26: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 511ms/step - loss: 0.7346 - accuracy: 0.3222 - val_loss: 0.7953 - val_accuracy: 0.3000
# Epoch 27/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.3222
# Epoch 27: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 517ms/step - loss: 0.6927 - accuracy: 0.3222 - val_loss: 0.7231 - val_accuracy: 0.3000
# Epoch 28/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6574 - accuracy: 0.3222
# Epoch 28: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 523ms/step - loss: 0.6574 - accuracy: 0.3222 - val_loss: 0.6859 - val_accuracy: 0.3000
# Epoch 29/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.3222
# Epoch 29: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 544ms/step - loss: 0.6353 - accuracy: 0.3222 - val_loss: 0.6443 - val_accuracy: 0.3000
# Epoch 30/50
# 45/45 [==============================] - ETA: 0s - loss: 0.9529 - accuracy: 0.3222
# Epoch 30: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 529ms/step - loss: 0.9529 - accuracy: 0.3222 - val_loss: 0.6979 - val_accuracy: 0.3000
# Epoch 31/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7234 - accuracy: 0.3222
# Epoch 31: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 550ms/step - loss: 0.7234 - accuracy: 0.3222 - val_loss: 0.7106 - val_accuracy: 0.3000
# Epoch 32/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7298 - accuracy: 0.3222
# Epoch 32: val_loss did not improve from 0.55147
# 45/45 [==============================] - 26s 569ms/step - loss: 0.7298 - accuracy: 0.3222 - val_loss: 0.7139 - val_accuracy: 0.3000
# Epoch 33/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7033 - accuracy: 0.3222
# Epoch 33: val_loss did not improve from 0.55147
# 45/45 [==============================] - 26s 582ms/step - loss: 0.7033 - accuracy: 0.3222 - val_loss: 0.6842 - val_accuracy: 0.3000
# Epoch 34/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6244 - accuracy: 0.3222
# Epoch 34: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 514ms/step - loss: 0.6244 - accuracy: 0.3222 - val_loss: 0.6933 - val_accuracy: 0.3000
# Epoch 35/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5645 - accuracy: 0.3222
# Epoch 35: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 546ms/step - loss: 0.5645 - accuracy: 0.3222 - val_loss: 0.7091 - val_accuracy: 0.3000
# Epoch 36/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5243 - accuracy: 0.3222
# Epoch 36: val_loss did not improve from 0.55147
# 45/45 [==============================] - 23s 518ms/step - loss: 0.5243 - accuracy: 0.3222 - val_loss: 0.7002 - val_accuracy: 0.3000
# Epoch 37/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.3222
# Epoch 37: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 531ms/step - loss: 0.4895 - accuracy: 0.3222 - val_loss: 0.7544 - val_accuracy: 0.3000
# Epoch 38/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.3222
# Epoch 38: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 538ms/step - loss: 0.4398 - accuracy: 0.3222 - val_loss: 0.6894 - val_accuracy: 0.3000
# Epoch 39/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.3222
# Epoch 39: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 546ms/step - loss: 0.5298 - accuracy: 0.3222 - val_loss: 0.6687 - val_accuracy: 0.3000
# Epoch 40/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6422 - accuracy: 0.3222
# Epoch 40: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 551ms/step - loss: 0.6422 - accuracy: 0.3222 - val_loss: 0.7022 - val_accuracy: 0.3000
# Epoch 41/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.3222
# Epoch 41: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 556ms/step - loss: 0.6863 - accuracy: 0.3222 - val_loss: 0.6618 - val_accuracy: 0.3000
# Epoch 42/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.3222
# Epoch 42: val_loss did not improve from 0.55147
# 45/45 [==============================] - 26s 575ms/step - loss: 0.6288 - accuracy: 0.3222 - val_loss: 0.6077 - val_accuracy: 0.3000
# Epoch 43/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.3222
# Epoch 43: val_loss did not improve from 0.55147
# 45/45 [==============================] - 26s 570ms/step - loss: 0.6894 - accuracy: 0.3222 - val_loss: 0.6189 - val_accuracy: 0.3000
# Epoch 44/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6362 - accuracy: 0.3222
# Epoch 44: val_loss did not improve from 0.55147
# 45/45 [==============================] - 26s 571ms/step - loss: 0.6362 - accuracy: 0.3222 - val_loss: 0.7010 - val_accuracy: 0.3000
# Epoch 45/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.3222
# Epoch 45: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 542ms/step - loss: 0.5534 - accuracy: 0.3222 - val_loss: 0.6798 - val_accuracy: 0.3000
# Epoch 46/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.3222
# Epoch 46: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 545ms/step - loss: 0.6223 - accuracy: 0.3222 - val_loss: 0.6811 - val_accuracy: 0.3000
# Epoch 47/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.3222
# Epoch 47: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 560ms/step - loss: 0.5943 - accuracy: 0.3222 - val_loss: 0.6577 - val_accuracy: 0.3000
# Epoch 48/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.3222
# Epoch 48: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 539ms/step - loss: 0.4672 - accuracy: 0.3222 - val_loss: 0.6247 - val_accuracy: 0.3000
# Epoch 49/50
# 45/45 [==============================] - ETA: 0s - loss: 0.8214 - accuracy: 0.3222
# Epoch 49: val_loss did not improve from 0.55147
# 45/45 [==============================] - 25s 562ms/step - loss: 0.8214 - accuracy: 0.3222 - val_loss: 0.7231 - val_accuracy: 0.3000
# Epoch 50/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5250 - accuracy: 0.3222
# Epoch 50: val_loss did not improve from 0.55147
# 45/45 [==============================] - 24s 544ms/step - loss: 0.5250 - accuracy: 0.3222 - val_loss: 0.7185 - val_accuracy: 0.3000

# %%
#@title Instructor Solution
cnn_performance = cnn_model.evaluate(X_test_cnn, y_test, batch_size=64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20904\221118037.py in <module>
#       1 #@title Instructor Solution
# ----> 2 cnn_performance = cnn_model.evaluate(X_test_cnn, y_test, batch_size=64)
#
# NameError: name 'X_test_cnn' is not defined

# %%
#@title Instructor Solution
plot_graphs(cnn_history, cnn_performance)

# %%
#@title Run this to build your transfer learning model { display-mode: "form" }

import keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D
from keras.wrappers.scikit_learn import KerasClassifier
from keras.applications.vgg16 import VGG16

# load the vgg network that is an 'expert' at 'imagenet' but do not include the FC layers
vgg_expert = VGG16(weights = 'imagenet', include_top = False, input_shape = (48, 48, 3))

# we add the first 12 layers of vgg to our own model vgg_model
vgg_model = Sequential()
vgg_model.add(vgg_expert)

# and then add our own layers on top of it
vgg_model.add(GlobalAveragePooling2D())
vgg_model.add(Dense(1024, activation = 'relu'))
vgg_model.add(Dropout(0.3))
vgg_model.add(Dense(512, activation = 'relu'))
vgg_model.add(Dropout(0.3))
vgg_model.add(Dense(5, activation = 'sigmoid'))

# finally, we build the vgg model and turn it on so we can use it!
vgg_model.compile(loss = 'categorical_crossentropy', 
          optimizer = SGD(lr=1e-4, momentum=0.95), 
          metrics=['accuracy'])

X_TRAIN = np.array([np.transpose(np.array([X_train_cnn[ix].squeeze() for i in range(3)]), (1,2,0)) for ix in range(len(X_train))])
X_TEST = np.array([np.transpose(np.array([X_test_cnn[ix].squeeze() for i in range(3)]), (1,2,0)) for ix in range(len(X_test))])

#training the model
vgg_history = vgg_model.fit(X_TRAIN, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=[checkpoint],
          validation_data=(X_TEST, y_test),
          shuffle=True)

# %%
#@title Instructor Solution
vgg_performance = vgg_model.evaluate(X_TEST, y_test, batch_size=64)

# %%
#@title Instructor Solution
plot_graphs(vgg_history, vgg_performance)

# %%
from sklearn.neighbors import KNeighborsClassifier

# pixel-based knn classification accuracy... this will take a few minutes 
knn_pixel = KNeighborsClassifier(n_neighbors=3)
knn_pixel.fit(X_train, y_train)
knn_predictions_pixel = knn_pixel.predict(X_test)
knn_accuracy_pixel = np.mean(knn_predictions_pixel.argmax(1) == y_test.argmax(1))

# landmark-based knn classification accuracy... this will take a few minutes 
knn_lm = KNeighborsClassifier(n_neighbors=3)
knn_lm.fit(X_train_lm, y_train_lm)
knn_predictions_lm = knn_lm.predict(X_test_lm)
knn_accuracy_lm = np.mean( knn_predictions_lm.argmax(1) == y_test_lm.argmax(1))

# chance accuracy
chance_accuracy = 1/n_labels

# human accuracy
human_accuracy = .65

# %%
def compare_learning(mlp, lm, cnn, vgg, benchmarks): 

  plt.figure(figsize=[7, 5])  

  # summarize history for accuracy

  plt.xticks(range(4, epochs+1,5), range(5, epochs+1,5) )
  
  plt.title('Performance of multiple models across training', y=1.05, fontsize=15)

  plt.ylim([.15, .72])

  plt.plot(lm.history['val_accuracy'], linestyle='-', color='purple', )
  plt.plot(mlp.history['val_accuracy'], linestyle='--', color='purple')

  plt.plot(vgg.history['val_accuracy'],color='blue', linestyle='-', linewidth=2)
  plt.plot(cnn.history['val_accuracy'],color='red', linestyle='-', linewidth=2)
  
  plt.ylabel('Accuracy', fontsize=15)
  plt.xlabel('Training Epoch', fontsize=15)


  plt.legend(['MLP''$_{landmarks}$', 'MLP''$_{pixels}$', 'CNN''$_{pretrained}$', 'CNN''$_{from.scratch}$'],
             framealpha=0, title_fontsize=9,loc=8)

  plt.xticks(range(4, epochs+1,5), range(5, epochs+1,5) )
  plt.ylim([.11, .72])

  for i_benchmark in benchmarks: 
    plt.scatter(x=epochs, y=references[i_benchmark], color='black', marker='_', s=200) 
    plt.annotate('%s: %d%%'%( i_benchmark, references[i_benchmark] *100), xy=(epochs+1, references[i_benchmark]-.005), size=10, color='black', ha='left') 
  plt.annotate('Important References', xy=(epochs+.5, .69), size=10, color='black', ha='left', fontweight='bold') 

  plt.ylim([.11, .72])
  plt.gca().spines['right'].set_color('none')
  plt.gca().spines['top'].set_color('none')

  plt.show()

# %%
references = {'$KNN_{pixel}$ Accuracy': knn_accuracy_pixel, '$KNN_{landmark}$ Accuracy': knn_accuracy_lm, 'Human Accuracy': human_accuracy, 'chance': chance_accuracy}

# %%
compare_learning(mlp_history, lm_history, cnn_history, vgg_history, references)
